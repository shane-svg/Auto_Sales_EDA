# %% [markdown]
# #   <center> Auto_Sales_Analysis</center>

# %% [markdown]
# ## **Table of Contents**
#
# 1. [**Problem Statement**](#section1)<br>
# 2. [**Importing Packages**](#section2)<br>
# 3. [**Loading Data**](#section3)<br>
# 4. [**Description of the Dataset**](#section401)<br>
# 5. [**Exploratory Data Analysis**](#section6)<br>
# 6. [**Conclusion**](#section7)<br>

# %% [markdown]
# <a id=section1></a>
#
# ---
# # **1. Problem Statement**
# ---
#
#
# ## Sales Trends Over Time:
#
# How do total sales vary month-to-month and year-to-year?
# What are the peak sales months?
#
# ## Product Line Analysis:
#
# Which product lines generate the most revenue?
# What is the average quantity ordered for each product line?
# Are there any noticeable trends in the popularity of specific product lines over time?
#
# ## Order Details:
#
# What is the distribution of the order quantities (QUANTITYORDERED)?
# How does the PRICEEACH vary across different products and product lines?
# What is the average sales value per order?
#
# ## Customer Insights:
#
# Which countries/cities have the highest number of orders?
# Who are the top customers in terms of total sales?
#
# ## Order Status:
#
# What proportion of orders are shipped, cancelled, or on hold?
# How does the status distribution vary across different months or years?
#
# ## Order Timing:
#
# What is the average time (DAYS_SINCE_LASTORDER) between orders for customers?
# Are there any patterns in order frequency for different product lines or deal sizes?
#
# ## Sales Performance:
#
# How does the MSRP (Manufacturer's Suggested Retail Price) compare to the PRICEEACH?
# Are there any significant differences in sales performance across different order line numbers?
#
# ## Geographical Insights:
#
# What are the top performing regions (countries or cities) in terms of total sales?
# How do sales vary geographically?
#
# ## Deal Size Analysis:
#
# What are the average sales for different deal sizes (Small, Medium, Large)?
# How does the quantity ordered and sales value differ across various deal sizes?
#
# ## Correlation and Trends:
#
# Are there any correlations between QUANTITYORDERED, PRICEEACH, and SALES?
# How does the number of days since the last order (DAYS_SINCE_LASTORDER) affect the quantity ordered and sales?
# These questions can guide you in uncovering patterns, trends, and insights within your dataset.

# %% [markdown]
# <a id=section2></a>
#
# ---
# # **2. Importing Libraries**
# ---

# %%
import numpy as np
                 
#--------------------------------------------------------------------------------
import pandas as pd
  
#--------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns            

#-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <a id=section3></a>
#
# ---
# # **3. Loading Data**
# ---

# %%
data= pd.read_csv("Auto sales data.csv")
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %% [markdown]
# <a id=section4></a>
#
# ---
# # **4. Data Description**
# ---
#
# <br>

# %%
data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %% [markdown]
# <a id=section6></a>
#
# ---
# # **5. Exploratory Data Analysis**
# ---

# %% [markdown]
# ## Sales Trends Over Time:

# %% [markdown]
# ###  Month wise average sales

# %%
data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
data["Month"]=data["order_date_dt"].dt.month
data["year"]=data["order_date_dt"].dt.year
data["day"]=data["order_date_dt"].dt.day
data.groupby(["year","Month"])["SALES"].mean().reset_index()
sns.barplot(data=data.groupby(["year","Month"])["SALES"].mean().reset_index(),x="Month",y="SALES",hue="year")
plt.title("Month wise average sale")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_6220\562271408.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])

# %% [markdown]
# ###  Year wise average sales

# %%
data.groupby(["year","Month"])["SALES"].mean().reset_index()
sns.barplot(data=data.groupby(["year","Month"])["SALES"].mean().reset_index(),x="year",y="SALES",hue="Month",palette="cool")
plt.title("year wise average sale")
plt.show()

# %% [markdown]
# ###  What are the peak sales months?

# %%
data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
data["Month"]=data["order_date_dt"].dt.month
monthly_sales=data.groupby("Month")["SALES"].mean()
print(f"the month which has peak sales is {monthly_sales.idxmax()}")
print(f"with sales of {monthly_sales.max()}")
# Out:
# the month which has peak sales is 4
# with sales of 3760.6233707865167
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\1491098395.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])

# %%
data.groupby("Month")["SALES"].mean().reset_index()
sns.barplot(data=data.groupby("Month")["SALES"].mean().reset_index(),x="Month",y="SALES",palette="cool")
plt.title("month wise average sale")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\657863884.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("Month")["SALES"].mean().reset_index(),x="Month",y="SALES",palette="cool")

# %% [markdown]
# ## Product Line Analysis:

# %% [markdown]
# ### Which product lines generate the most revenue?

# %%
product_sales=data.groupby("PRODUCTLINE")["SALES"].mean()
print(f"the product which generates the most revenue is {product_sales.idxmax()}")
print(f"with sales of {product_sales.max()}")
# Out:
# the product which generates the most revenue is Classic Cars
# with sales of 4049.387291886196

# %%
plt.figure(figsize=(15,8))
data.groupby("PRODUCTLINE")["SALES"].mean()
sns.barplot(data=data.groupby("PRODUCTLINE")["SALES"].mean().reset_index(),x="PRODUCTLINE",y="SALES",palette="cool")
plt.title("Productline wise revenue")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\3759015110.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("PRODUCTLINE")["SALES"].mean().reset_index(),x="PRODUCTLINE",y="SALES",palette="cool")

# %% [markdown]
# ### What is the average quantity ordered for each product line?

# %%
plt.figure(figsize=(10,6))

sns.barplot(data=data,x="PRODUCTLINE",y="QUANTITYORDERED",palette="cool")
plt.title("Productline wise average order-size")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_9776\159004070.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="PRODUCTLINE",y="QUANTITYORDERED",palette="cool")

# %% [markdown]
# ### Are there any noticeable trends in the popularity of specific product lines over time?

# %%
plt.figure(figsize=(15,6))
data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
data["year"]=data["order_date_dt"].dt.year
sns.barplot(data=data.groupby(["year","PRODUCTLINE"])["SALES"].mean().reset_index(),x="PRODUCTLINE",y="SALES",hue="year")
plt.title("Year wise trends of popularity of product lines")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_9776\608057561.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])

# %% [markdown]
# ## Order Details:

# %% [markdown]
# ### What is the distribution of the order quantities (QUANTITYORDERED)?

# %%
plt.figure(figsize=(15,6))
quantity_=data["QUANTITYORDERED"].value_counts().reset_index()
sns.histplot(x=data["QUANTITYORDERED"])
# Out:
# <Axes: xlabel='QUANTITYORDERED', ylabel='Count'>

# %% [markdown]
# ### How does the PRICEEACH vary across different products and product lines?

# %%
plt.figure(figsize=(15,6))
data.groupby(["PRODUCTLINE"])[["PRICEEACH"]].mean().reset_index()
sns.barplot(data=data.groupby(["PRODUCTLINE"])[["PRICEEACH"]].mean().reset_index(), x ="PRODUCTLINE", y="PRICEEACH",palette="cool")
plt.title("variation in priceeach based on Productline")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_9776\3449734240.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby(["PRODUCTLINE"])[["PRICEEACH"]].mean().reset_index(), x ="PRODUCTLINE", y="PRICEEACH",palette="cool")

# %% [markdown]
# ### What is the average sales value per order?

# %%
data["SALES"].mean()
# Out:
# 3553.0475828176195

# %% [markdown]
# ## Customer Insights:

# %% [markdown]
# ### Which countries have the highest number of orders?

# %%
country=data["COUNTRY"].value_counts().reset_index()
top_country=country.sort_values(by="count",ascending= False)
print(top_country.head())


plt.figure(figsize=(20,8))
data["COUNTRY"].value_counts().reset_index()
sns.histplot(x=data["COUNTRY"])



plt.show()
# Out:
#      COUNTRY  count
# 0        USA    928
# 1      Spain    342
# 2     France    314
# 3  Australia    185
# 4         UK    144

# %% [markdown]
# ### Which cities have the highest number of orders?

# %%
city=data["CITY"].value_counts().reset_index()
top_city=city.sort_values(by="count",ascending= False)
print(top_city.head())

plt.figure(figsize=(30,8))
data["CITY"].value_counts().reset_index()
sns.histplot(x=data["CITY"])

             
plt.show()
# Out:
#          CITY  count
# 0      Madrid    304
# 1  San Rafael    180
# 2         NYC    152
# 3   Singapore     79
# 4       Paris     70

# %%
# Out:
#          CITY  count
# 0      Madrid    304
# 1  San Rafael    180
# 2         NYC    152
# 3   Singapore     79
# 4       Paris     70

# %% [markdown]
# ### Who are the top customers in terms of total sales?

# %%
customer=data.groupby("CUSTOMERNAME")["SALES"].mean().reset_index()
top_customer=customer.sort_values(by="SALES",ascending= False)
top_customer.head()
# Out:
#                  CUSTOMERNAME        SALES
# 75           Super Scale Inc.  4674.827647
# 50                Mini Caravy  4233.604211
# 42  La Corne D'abondance, Co.  4226.246957
# 66               Royale Belge  4180.012500
# 55         Muscle Machine Inc  4119.519583

# %% [markdown]
# ## Order Status:

# %% [markdown]
# ### What proportion of orders are shipped, cancelled, or on hold?

# %%
status=data["STATUS"].value_counts().reset_index()
print(status)
sns.histplot(x=data["STATUS"])
# Out:
#        STATUS  count
# 0     Shipped   2541
# 1   Cancelled     60
# 2    Resolved     47
# 3     On Hold     44
# 4  In Process     41
# 5    Disputed     14
# <Axes: xlabel='STATUS', ylabel='Count'>

# %% [markdown]
# ### How does the status distribution vary across different months or years?

# %%
data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
data["year"]=data["order_date_dt"].dt.year
data.groupby("year")["STATUS"].value_counts().reset_index()
sns.barplot(data=data.groupby("year")["STATUS"].value_counts().reset_index(),y="count",x="STATUS",hue="year")
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\3029598773.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
# <Axes: xlabel='STATUS', ylabel='count'>

# %%
data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
data["month"]=data["order_date_dt"].dt.month
data.groupby("month")["STATUS"].value_counts().reset_index()
sns.barplot(data=data.groupby("month")["STATUS"].value_counts().reset_index(),y="count",x="STATUS",hue="month")
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\2982362267.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["order_date_dt"]=pd.to_datetime(data["ORDERDATE"])
# <Axes: xlabel='STATUS', ylabel='count'>

# %% [markdown]
# ## Order Timing:

# %% [markdown]
# ### What is the average time (DAYS_SINCE_LASTORDER) between orders for customers?

# %%
customer=data.groupby("CUSTOMERNAME")["DAYS_SINCE_LASTORDER"].mean().reset_index()
print(customer["DAYS_SINCE_LASTORDER"].mean())
customer
# Out:
# 1767.4411596342748
#                    CUSTOMERNAME  DAYS_SINCE_LASTORDER
# 0                AV Stores, Co.           1803.803922
# 1                  Alpha Cognac           2236.200000
# 2            Amica Models & Co.           1318.615385
# 3       Anna's Decorations, Ltd           1463.586957
# 4             Atelier graphique           1424.428571
# ..                          ...                   ...
# 84              Vida Sport, Ltd           1362.935484
# 85              Vitachrome Inc.           1591.880000
# 86     Volvo Model Replicas, Co           1319.789474
# 87  West Coast Collectables Co.           1714.769231
# 88            giftsbymail.co.uk           2180.807692
#
# [89 rows x 2 columns]

# %%
plt.figure(figsize=(15,8))
customer=data.groupby("CUSTOMERNAME")["DAYS_SINCE_LASTORDER"].mean().reset_index()
sns.barplot(data=customer, x="CUSTOMERNAME",y="DAYS_SINCE_LASTORDER",palette="cool")
plt.title("average time between orders for customers")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_10440\809508514.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=customer, x="CUSTOMERNAME",y="DAYS_SINCE_LASTORDER",palette="cool")

# %% [markdown]
# ### Are there any patterns in order frequency for different product lines or deal sizes?

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
quantity_=data["PRODUCTLINE"].value_counts().reset_index()
sns.histplot(x=data["PRODUCTLINE"])

plt.subplot(2,2,2)
quantity_=data["DEALSIZE"].value_counts().reset_index()
sns.histplot(x=data["DEALSIZE"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sales Performance:

# %% [markdown]
# ### How does the MSRP (Manufacturer's Suggested Retail Price) compare to the PRICEEACH?

# %%
data[["MSRP","PRICEEACH"]].plot(kind="kde",figsize=(15,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Are there any significant differences in sales performance across different order line numbers?

# %%
data.groupby("ORDERLINENUMBER")["SALES"].mean()
sns.barplot(data=data.groupby("ORDERLINENUMBER")["SALES"].mean().reset_index(),x="ORDERLINENUMBER",y="SALES",palette="cool")

plt.title("Productline wise revenue")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\2062478172.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("ORDERLINENUMBER")["SALES"].mean().reset_index(),x="ORDERLINENUMBER",y="SALES",palette="cool")

# %% [markdown]
# ## Geographical Insights:

# %% [markdown]
# ### How do sales vary geographically?

# %%
plt.figure(figsize=(15,6))
data.groupby("COUNTRY")["SALES"].mean()
sns.barplot(data=data.groupby("COUNTRY")["SALES"].mean().reset_index(),x="COUNTRY",y="SALES",palette="cool")

plt.title("country wise total sales")
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_11464\3768362224.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("COUNTRY")["SALES"].mean().reset_index(),x="COUNTRY",y="SALES",palette="cool")

# %% [markdown]
# ### What are the top performing regions (countries or cities) in terms of total sales?

# %%
customer=data.groupby("COUNTRY")["SALES"].mean().reset_index()
top_customer=customer.sort_values(by="SALES",ascending= False)
top_customer.head()
# Out:
#         COUNTRY        SALES
# 4       Denmark  3899.002381
# 16  Switzerland  3797.211613
# 15       Sweden  3684.459825
# 1       Austria  3673.864182
# 13    Singapore  3651.752025

# %% [markdown]
# ## Deal Size Analysis:

# %% [markdown]
# ### What are the average sales for different deal sizes (Small, Medium, Large)?

# %%
data.groupby("DEALSIZE")["SALES"].mean().reset_index()
sns.barplot(data=data.groupby("DEALSIZE")["SALES"].mean().reset_index(),x="DEALSIZE",y="SALES",palette="cool")
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_10196\1218733624.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("DEALSIZE")["SALES"].mean().reset_index(),x="DEALSIZE",y="SALES",palette="cool")
# <Axes: xlabel='DEALSIZE', ylabel='SALES'>

# %% [markdown]
# ### How does the quantity ordered and sales value differ across various deal sizes?

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
data1=data.groupby("DEALSIZE")["SALES"].mean().reset_index()
sns.barplot(data=data.groupby("DEALSIZE")["SALES"].mean().reset_index(),x="DEALSIZE",y="SALES",palette="cool")

plt.subplot(2,2,2)
data1=data.groupby("DEALSIZE")["QUANTITYORDERED"].mean().reset_index()
sns.barplot(data=data.groupby("DEALSIZE")["QUANTITYORDERED"].mean().reset_index(),x="DEALSIZE",y="QUANTITYORDERED",palette="cool")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\shesa\AppData\Local\Temp\ipykernel_10196\1750413864.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("DEALSIZE")["SALES"].mean().reset_index(),x="DEALSIZE",y="SALES",palette="cool")
# C:\Users\shesa\AppData\Local\Temp\ipykernel_10196\1750413864.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data.groupby("DEALSIZE")["QUANTITYORDERED"].mean().reset_index(),x="DEALSIZE",y="QUANTITYORDERED",palette="cool")

# %% [markdown]
# ## Correlation and Trends

# %% [markdown]
# ### Are there any correlations between QUANTITYORDERED, PRICEEACH, and SALES?

# %%
data[["QUANTITYORDERED","PRICEEACH","SALES"]].corr()
# Out:
#                  QUANTITYORDERED  PRICEEACH     SALES
# QUANTITYORDERED         1.000000   0.010161  0.553359
# PRICEEACH               0.010161   1.000000  0.808287
# SALES                   0.553359   0.808287  1.000000

# %% [markdown]
# ### How does the number of days since the last order (DAYS_SINCE_LASTORDER) affect the quantity ordered and sales?

# %%
data.groupby("DAYS_SINCE_LASTORDER")["SALES"].mean().reset_index()
sns.barplot(data=data.groupby("DAYS_SINCE_LASTORDER")["SALES"].mean().reset_index(),x="DAYS_SINCE_LASTORDER",hue="SALES")
# Out:
# <Axes: xlabel='DAYS_SINCE_LASTORDER'>
# C:\Users\shesa\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\shesa\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data.groupby("DAYS_SINCE_LASTORDER")["QUANTITYORDERED"].mean().reset_index()
sns.barplot(data=data.groupby("DAYS_SINCE_LASTORDER")["QUANTITYORDERED"].mean().reset_index(),x="DAYS_SINCE_LASTORDER",hue="QUANTITYORDERED")
# Out:
# <Axes: xlabel='DAYS_SINCE_LASTORDER'>
